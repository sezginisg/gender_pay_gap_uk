# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("UK Gender Pay Gap Data - 2017 to 2018.csv")

# %%
data.describe()
# Out:
#        DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# count           10563.000000             10563.000000          10540.000000
# mean               14.339638                11.798438              7.671461
# std                14.910806                15.842876            833.729072
# min              -400.000000              -196.500000         -82000.000000
# 25%                 5.000000                 0.700000              0.000000
# 50%                13.400000                 9.200000             22.000000
# 75%                22.900000                21.000000             53.000000
# max               159.000000               121.200000           3848.200000
#
#        DiffMedianBonusPercent  MaleBonusPercent  FemaleBonusPercent  \
# count            10540.000000      10563.000000        10563.000000
# mean               -21.750787         35.395617           33.929244
# std               1400.166499         36.330536           36.014743
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10563 entries, 0 to 10562
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   EmployerName               10563 non-null  object
#  1   Address                    10563 non-null  object
#  2   CompanyNumber              9204 non-null   object
#  3   SicCodes                   9997 non-null   object
#  4   DiffMeanHourlyPercent      10563 non-null  float64
#  5   DiffMedianHourlyPercent    10563 non-null  float64
#  6   DiffMeanBonusPercent       10540 non-null  float64
#  7   DiffMedianBonusPercent     10540 non-null  float64
#  8   MaleBonusPercent           10563 non-null  float64
#  9   FemaleBonusPercent         10563 non-null  float64
#  10  MaleLowerQuartile          10563 non-null  float64
#  11  FemaleLowerQuartile        10563 non-null  float64
#  12  MaleLowerMiddleQuartile    10563 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# EmployerName                    0
# Address                         0
# CompanyNumber                1359
# SicCodes                      566
# DiffMeanHourlyPercent           0
# DiffMedianHourlyPercent         0
# DiffMeanBonusPercent           23
# DiffMedianBonusPercent         23
# MaleBonusPercent                0
# FemaleBonusPercent              0
# MaleLowerQuartile               0
# FemaleLowerQuartile             0
# MaleLowerMiddleQuartile         0
# FemaleLowerMiddleQuartile       0
# MaleUpperMiddleQuartile         0
# FemaleUpperMiddleQuartile       0
# MaleTopQuartile                 0
# FemaleTopQuartile               0
# CompanyLinkToGPGInfo         2764
# ResponsiblePerson            1677
# EmployerSize                    0
# CurrentName                     0
# SubmittedAfterTheDeadline       0
# DueDate                         0
# DateSubmitted                   0
# dtype: int64

# %%
data.head()
# Out:
#                            EmployerName  \
# 0       "Bryanston School",Incorporated
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED
# 2                           118 LIMITED
# 3                     123 EMPLOYEES LTD
# 4                          1610 LIMITED
#
#                                              Address CompanyNumber SicCodes  \
# 0       Bryanston House, Blandford, Dorset, DT11 0PX      00226143    85310
# 1   19 Smith's Place, Leith Walk, Edinburgh, EH6 8NU      SC016876    47730
# 2  3 Alexandra Gate Ffordd Pengam, Ground Floor, ...      03951948    61900
# 3          34 Roundhay Road, Leeds, England, LS7 1AB      10530651    78300
# 4  Hestercombe House, Cheddon Fitzpaine, Taunton,...      06727055    93110
#
#    DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# 0                   18.0                     28.2                   0.0
# 1                    2.3                     -2.7                  15.0
# ...

# %%
data.tail()
# Out:
#                              EmployerName  \
# 10558                             ZPG PLC
# 10559  ZURICH EMPLOYMENT SERVICES LIMITED
# 10560  ZURICH UK GENERAL SERVICES LIMITED
# 10561               ZUTO HOLDINGS LIMITED
# 10562          ZWANENBERG FOOD UK LIMITED
#
#                                                  Address CompanyNumber  \
# 10558  The Cooperage, 5 Copper Row, London, England, ...      09005884
# 10559  The Grange, Bishops Cleeve, Cheltenham, Glouce...      00243883
# 10560  The Zurich Centre 3000 Parkway, Whiteley, Fare...      03843124
# 10561  Winterton House, Winterton Way, Macclesfield, ...      08563366
# 10562  Station Road, Minsterley, Shrewsbury, Shropshi...      01032611
#
#               SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 10558            63120                   27.8                     17.5
# 10559  78300,\r\n82990                   30.0                     33.7
# ...

# %%
data['CompanyNumber'].value_counts().sum()
# Out:
# 9204

# %%
data.loc[data['DiffMeanBonusPercent'].isnull()]
# Out:
#                                            EmployerName  \
# 834                                     BANK OF IRELAND
# 835                            BANK OF IRELAND (UK) PLC
# 1069                                 BISHOP FLEMING LLP
# 1076     Black Country Partnership NHS Foundation Trust
# 1103          Blessed Peter Snow Catholic Academy Trust
# 1380         Brothers of Charity Services in Lancashire
# 2031             CLASS 1 PERSONNEL ( HAMMERSMITH )  LTD
# 2142                                      COMPAID TRUST
# 3391                            FOR UNDER FIVES LIMITED
# 3978                   HALL & KAY FIRE SERVICES LIMITED
# 4223             HIGHLANDS AND ISLANDS AIRPORTS LIMITED
# 4384                                 Hull College Group
# 4950                       Kenton Schools Academy Trust
# 4967                                  Keychange Charity
# 5112                                 Lady Margaret Hall
# 5361                   Liverpool John Moores University
# ...

# %%
data.loc[data['DiffMedianBonusPercent'].isnull()]
# Out:
#                                            EmployerName  \
# 834                                     BANK OF IRELAND
# 835                            BANK OF IRELAND (UK) PLC
# 1069                                 BISHOP FLEMING LLP
# 1076     Black Country Partnership NHS Foundation Trust
# 1103          Blessed Peter Snow Catholic Academy Trust
# 1380         Brothers of Charity Services in Lancashire
# 2031             CLASS 1 PERSONNEL ( HAMMERSMITH )  LTD
# 2142                                      COMPAID TRUST
# 3391                            FOR UNDER FIVES LIMITED
# 3978                   HALL & KAY FIRE SERVICES LIMITED
# 4223             HIGHLANDS AND ISLANDS AIRPORTS LIMITED
# 4384                                 Hull College Group
# 4950                       Kenton Schools Academy Trust
# 4967                                  Keychange Charity
# 5112                                 Lady Margaret Hall
# 5361                   Liverpool John Moores University
# ...
